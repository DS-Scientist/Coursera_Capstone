# %% [markdown]
# # IBM Applied Data Science Course

# %% [markdown]
# # Capstone Project - Battle of the Neighborhoods (Week 1)

# %% [markdown]
# For this week, you will be required to submit the following:

# %% [markdown]
# A description of the problem and a discussion of the background. (15 marks)

# %% [markdown]
# A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# # Project Name: Where is the best neighborhood in New York City to open an Italian restaurant?

# %%
Project Name: Where is the best neighborhood in New York City to open a Japanese restaurant?

# %% [markdown]
# # Introduction

# %% [markdown]
# New York - one of the great metropolitan cities in the world, is comprised of 5 boroughs: Manhattan, Brooklyn, Bronx, Queens, and Staten Island.

# %% [markdown]
# (Manhattan is the most well-known and the borough most identified with the city).

# %% [markdown]
# With a dense population, New York City represents a significant global crossroad of diverse cultures and an unlimited choice of cuisines.

# %% [markdown]
# # Business Problem

# %% [markdown]
# Opening and sustaining a successful restaurant in New York City is extremely competitive. Location is always an important factor in whether a business succeeds or fails. This study, in particular, aims to determine an ideal location to launch a Japanese restaurant by a potential business investor. However, to minimize financial risk, it is essential, with data science, to take a more comprehensive look across all 5 boroughs.

# %% [markdown]
# In the US , Japanese restaurants can be found in virually every metropolitan area and there is a groing trend toward eating more healthfully. This type of cuisine offers many appealing options including sushi, edamame, soba/udon/ramen noodles.

# %% [markdown]
# To address the problem of the most advantageous New York City neighborhood to open a Japanese restaurant, the following questions need to be asked:

# %% [markdown]
# How many neighborhoods are located within each of the 5 boroughs in New York City?

# %% [markdown]
# How many Japanese restaurants are located within the most populous borough?

# %% [markdown]
# What are the reviews/rankings of the Japanese restaurants in these areas?

# %% [markdown]
# # Data Sources & Description

# %% [markdown]
# As noted above, to best analyze the problem, it is necessary to consider data on all 5 New York City boroughs: neighborhoods, latitude/longitude, restaurants, and customer tips/rankings/likes.

# %% [markdown]
# The following data sources will be leveraged to generate useful insights:

# %% [markdown]
# 1)https://cocl.us/new_york_dataset [from https://geo.nyu.edu/catalog/nyu_2451_34572]
# for New York City data with boroughs (Manhattan, Brooklyn, Bronx, Queens, and Staten Island), neighborhoods, latitudes, and longitudes.
# Data will be sourced and organized into a pandas dataframe.

# %% [markdown]
# 2)https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm/data?no_mobile=true
# for additional New York City data with borough/neighborhood boundaries in a dataframe.

# %% [markdown]
# 3)https://foursquare.com/ for New York City Japanese restaurants – locations and customer rankings/tips/likes (using FourSquare API to filter out relevant columns of information).

# %% [markdown]
# The collected data will be sorted based on rankings (boroughs/neighborhoods), using dataframes to describe statistics, and plotted into visual graphs/maps (folium library to visualize location data) to draw informed insights to make an appropriate recommendation.

# %% [markdown]
# # Methodology

# %% [markdown]
# -Data will be collected from https://cocl.us/new_york_dataset and https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm/data?no_mobile=true and cleansed for processing into a dataframe.

# %% [markdown]
# -FourSquare https://foursquare.com/ will be used to locate all venues and then filtered by Japanese restaurants. Ratings, tips, and likes by users will be counted and added to the dataframe. (To pull in data for the venues, for example, the Foursquare API is set up to create a list of places within a specified radius. Foursquare supplies the names, locations, and venue type of the surrounding businesses.)

# %% [markdown]
# -Data will be sorted based on rankings.

# %% [markdown]
# -The data will also be visually assessed using graphs from Python and Folium libraries.
